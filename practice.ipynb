# %%
  #Demonstration of variables
   
a = "Swastika"
b = 20
c = 5.8
d = True

print(f"My name is {a}, I am {b} years old, my height is {c} feet and it is {d} that I like programming")
# Out:
# My name is Swastika, I am 20 years old, my height is 5.8 feet and it is True that I like programming

# %%
a = 50
result = float(a)
print(result)
print(type(result))
# Out:
# 50.0
# <class 'float'>

# %%
a=input("Enter your name:")
b=int(input("Enter your age:"))
c=float(input("Enter your height in feet:"))
d=bool(input("Do you like programming? (True/False):"))
print(f"My name is {a}, I am {b} years old, my height is {c} feet and it is {d} that I like programming")

# %%
#perform arithmrtic operations
a = int(input("Enter first number:"))
b = int(input("Enter second number:"))

sum = a + b
print(f"The sum of {a} and {b} is: {sum}")
substraction = a - b
print("The difference is:", substraction)
multiplication= a * b
print("The multiplication is:", multiplication)
division = a / b
print("The division is:", division)
modulo = a % b
print("The modulo is:", modulo)
# Out:
# The sum of 12 and 8 is: 20
# The difference is: 4
# The multiplication is: 96
# The division is: 1.5
# The modulo is: 4

# %%
#Type conversion
x = 5
y = 2.5
z = "10"
s = 1j 

#convert from int to float:
a = float(x)
print(a)

#convert from float to int:
b = int(y)
print(b)

#convert from str to int:
c = int(z)
print(c)

#convert from int to complex:
d = complex(x)
print(d)
# Out:
# 5.0
# 2
# 10
# (5+0j)

# %%
import random

print(random.randrange(15, 20))
# Out:
# 16
